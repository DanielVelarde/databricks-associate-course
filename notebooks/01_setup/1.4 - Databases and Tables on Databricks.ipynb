-- %%
USE CATALOG course_catalog;

-- %%
CREATE TABLE managed_default
VALUES (3 INT, 2 INT, 1 INT)

-- %%
DESCRIBE EXTENDED managed_default

-- %%
CREATE TABLE external_default
  (width INT, length INT, height INT)
LOCATION 'dbfs:/mnt/demo/external_default';

INSERT INTO external_default
VALUES (3 INT, 2 INT, 1 INT)

-- %%
SHOW CATALOGS;

-- %%
CREATE TABLE IF NOT EXISTS hive_metastore.default.external_default
  (width INT, length INT, height INT);

INSERT INTO hive_metastore.default.external_default
VALUES (3, 2, 1);

-- %%
-- 1. Create a catalog for your course work
CREATE CATALOG IF NOT EXISTS course_catalog;

-- 2. Create a schema (database) inside that catalog
CREATE SCHEMA IF NOT EXISTS course_catalog.delta_lab;

-- 3. Create your table inside your new secure space
CREATE TABLE course_catalog.delta_lab.external_default
  (width INT, length INT, height INT);

-- 4. Insert the data
INSERT INTO course_catalog.delta_lab.external_default
VALUES (3, 2, 1);

-- %%
DROP CATALOG IF EXISTS hive_metascore CASCADE;

-- %%
-- Step 1: Make sure you are in your new catalog
USE CATALOG course_catalog;
USE SCHEMA delta_lab;

-- Step 2: Create the table WITHOUT the 'LOCATION' line
CREATE TABLE IF NOT EXISTS course_catalog.delta_lab.external_default 
  (width INT, length INT, height INT);

-- Step 3: Insert the values (without repeating the INT type)
INSERT INTO external_default
VALUES (3, 2, 1);

-- %%
CREATE SCHEMA custom
MANAGED LOCATION 'disableddbfs://host-placeholder/Shared/schemas/custom.db'
